# %% [markdown]
# <a href="https://colab.research.google.com/github/Harjashan0210/TASK-WORK2004/blob/main/pbl3_0_ASSIGNMENT_linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Q1
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/students.csv")
df
df.isnull().sum()
df.info()
df.describe()
df.dropna()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Study Hours  7 non-null      int64
#  1   Attendance   7 non-null      int64
#  2   Marks        7 non-null      int64
# dtypes: int64(3)
# memory usage: 300.0 bytes
#    Study Hours  Attendance  Marks
# 0            2          75     55
# 1            3          80     60
# 2            4          85     65
# 3            5          90     72
# 4            6          88     78
# 5            7          92     85
# 6            8          95     90

# %%
marks = df["Marks"]
mean_marks = np.mean(marks)
print("Mean:", mean_marks)
median_marks = np.median(marks)
print("Median:", median_marks)
std_marks = np.std(marks)
print("Standard Deviation:", std_marks)
# Out:
# Mean: 72.14285714285714
# Median: 72.0
# Standard Deviation: 12.016994768464622

# %%
plt.hist(df["Marks"], bins=5)
plt.xlabel("Marks")
plt.ylabel("Frequency")
plt.title("Histogram of Marks")
plt.show()

# %%
plt.scatter(df['Study Hours'],df['Marks'])
plt.xlabel("Study Hours")
plt.ylabel("Marks")
plt.title("Scatter Plot of Study Hours vs Marks")
plt.show()

# %%
X = df[["Study Hours"]]
y = df["Marks"]
model=LinearRegression()
model.fit(X,y)
predicted = model.predict(X)
print("Predicted Values:")
print(predicted)
# Out:
# Predicted Values:
# [54.14285714 60.14285714 66.14285714 72.14285714 78.14285714 84.14285714
#  90.14285714]

# %%
plt.scatter(df["Study Hours"], df["Marks"], label="Actual Data")
plt.plot(df["Study Hours"], predicted, color="red", label="Regression Line")
plt.xlabel("Study Hours")
plt.ylabel("Marks")
plt.title("Linear Regression")
plt.legend()
plt.show()

# %%
#Q2

df2=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/car_mileage.csv")
df2
# Out:
#    Engine Size  Car Weight  Mileage
# 0          130        3504     7.64
# 1          165        3693     6.80
# 2          150        3436     7.22
# 3          140        3433     7.01
# 4          198        4341     5.95
# 5          220        4354     5.52
# 6          215        4312     5.74
# 7          225        4425     5.52
# 8          190        3850     6.37
# 9          115        3090     8.50

# %%
df2.describe()
# Out:
#        Engine Size   Car Weight    Mileage
# count    10.000000    10.000000  10.000000
# mean    174.800000  3843.800000   6.627000
# std      40.074375   483.739094   0.990208
# min     115.000000  3090.000000   5.520000
# 25%     142.500000  3453.000000   5.792500
# 50%     177.500000  3771.500000   6.585000
# 75%     210.750000  4333.750000   7.167500
# max     225.000000  4425.000000   8.500000

# %%
# Out:
#        Engine Size   Car Weight    Mileage
# count    10.000000    10.000000  10.000000
# mean    174.800000  3843.800000   6.627000
# std      40.074375   483.739094   0.990208
# min     115.000000  3090.000000   5.520000
# 25%     142.500000  3453.000000   5.792500
# 50%     177.500000  3771.500000   6.585000
# 75%     210.750000  4333.750000   7.167500
# max     225.000000  4425.000000   8.500000

# %%
print("Mean=", np.mean(df2["Mileage"]))
print("Median=", np.median(df2["Mileage"]))
print("Standard=", np.std(df2["Mileage"]))
# Out:
# Mean= 6.627
# Median= 6.585
# Standard= 0.9393939535679373

# %%
plt.scatter(df2["Car Weight"], df2["Mileage"])
plt.xlabel("Car Weight")
plt.ylabel("Mileage")
plt.title("Weight vs Mileage")
plt.show()

# %%
plt.hist(df2["Mileage"], bins=5)
plt.xlabel("Mileage")
plt.ylabel("Frequency")
plt.title("Histogram of Mileage")
plt.show()

# %%
X = df2[["Engine Size"]]
y = df2["Mileage"]
model = LinearRegression()
model.fit(X, y)
predicted = model.predict(X)
print(predicted)
# Out:
# [7.70563929 6.86295234 7.22410389 7.46487159 6.06841894 5.53873
#  5.65911385 5.41834616 6.2610331  8.06679083]

# %%
plt.scatter(df2["Engine Size"], df2["Mileage"], label="Actual Data")
plt.plot(df2["Engine Size"], predicted, color="red", label="Regression Line")

plt.xlabel("Engine Size")
plt.ylabel("Mileage")
plt.title("Linear Regression")
plt.legend()
plt.show()
